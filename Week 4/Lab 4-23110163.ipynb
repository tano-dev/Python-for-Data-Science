# %% [markdown]
# <h1 align="center">A Game of Chance</h1>

# %% [markdown]
# In this section, we simulate the popular dice game known as “craps.” Here is the requirements statement:
#
# <i>You roll two six-sided dice, each with faces containing one, two, three, four, five and six spots, respectively. When the dice come to rest, the sum of the spots on the two upward faces is calculated. If the sum is 7 or 11 on the first roll, you win. If the sum is 2, 3 or 12 on the first roll (called “craps”), you lose (i.e., the “house” wins). If the sum is 4, 5, 6, 8, 9 or 10 on the first roll, that sum becomes your “point.” To win, you must continue rolling the dice until you “make your point” (i.e., roll that same point value). You lose by rolling a 7 before making your point.</i>

# %% [markdown]
# ![Lab 4 - A game of change.png](attachment:b67d93d8-cee6-43fb-9c49-6a647f9d3ec5.png)

# %%
"""Simulating the dice game Craps."""
import random

def rollDice():
    """Roll two dice and return their face values as a tuple."""
    
def displayDice(dice):
    """Display one roll of the two dice."""
    
# first roll

# determine game status and point, based on first roll

# if sum of dice is 7 or 11: won

# if sum of dice is 2, 3 or 12: lost

# else, remember the point

    # continue rolling until player wins or loses
    
        # if sum of dice is equal to the point => win by making point
        
        # else if sum of dice is equal to 7 => lose
        
# display "wins" or "loses" message

# %% [markdown]
# ## Instructions

# %% [markdown]
# #### Function rollDice — Returning Multiple Values Via a Tuple

# %% [markdown]
# Function <code>rollDice</code> simulates rolling two dice on each roll.The empty parameter list indicates that <code>rollDice</code> does not require arguments to perform its task.
#
# The built-in and custom functions you’ve called so far each return one value. Sometimes it’s useful to return more than one value, as in rollDice, which returns both die values as a tuple. To create a tuple, separate its values with commas:
#
# <code>(die1, die2)</code>
#
# This is known as packing a tuple.

# %%
"""Simulating the dice game Craps."""
import random

# %%
def rollDice():
    """Roll two dice and return their face values as a tuple."""

# %% [markdown]
# #### Function displayDice
#
# To use a tuple’s values, you can assign them to a comma-separated list of variables, which unpacks the tuple. To display each roll of the dice, the function displayDice unpacks the tuple argument it receives. The number of variables to the left of = must match the number of elements in the tuple; otherwise, a ValueError occurs.
#
# The function prints a formatted string containing both die values and their sum. We calculate the sum of the dice by passing the tuple to the built-in sum function — like a list, a tuple is a sequence.

# %%
def displayDice(dice):
    """Display one roll of the two dice."""
    # unpack the tuple into variables die1 and die2

# %% [markdown]
# #### First Roll
#
# Roll the dice and display the results.
#
# Calculates the sum of the dice.
#
# You can win or lose on the first roll or any subsequent roll.

# %%
dieValues = rollDice() # first roll
displayDice(dieValues)

# %% [markdown]
# If you roll a 7 or 11, you won on the first roll.
#
# If you roll a 2, 3 or 12, you lost on the first roll.

# %% [markdown]
# #### Subsequent Rolls

# %% [markdown]
# Each loop iteration calls rollDice, displays the die values and calculates their sum. If the sum of dice is equal to the point or 7, you won or lost, respectively, and the loop terminates. Otherwise, the while loop continues executing with the next roll.
