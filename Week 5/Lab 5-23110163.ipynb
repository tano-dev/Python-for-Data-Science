# %% [markdown]
# <h1 align="center">Simulation and Static
# Visualizations</h1>

# %% [markdown]
# We use two open-source visualization libraries — Seaborn and Matplotlib — to display static bar charts showing the final results of a six-sided-die-rolling simulation.

# %% [markdown]
# #### Sample Graphs for 600, 60,000 and 6,000,000 Die Rolls

# %% [markdown]
# The screen capture below shows a vertical bar chart that for 600 die rolls summarizes the frequencies with which each of the six faces appear, and their percentages of the total. Seaborn refers to this type of graph as a <b>bar plot</b>:

# %% [markdown]
# ![Lab 5 - Sample Graphs for 600, 60,000 and 6,000,000 Die Rolls.png](attachment:7d0f41b6-5c46-4a58-b098-161a62bf177b.png)

# %% [markdown]
# We’ll discuss how to control the plot’s appearance and contents:
#
# - the graph title inside the window (Rolling a Six-Sided Die 600 Times),
# - the descriptive labels Die Value for the x-axis and Frequency for the y-axis,
# - the text displayed above each bar, representing the frequency and percentage of the
# total rolls, and
# - the bar colors.

# %% [markdown]
# #### Importing the Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import seaborn as sns

# %% [markdown]
# 1. The matplotlib.pyplot module contains the Matplotlib library’s graphing capabilities that we use. This module typically is imported with the name plt.
# 2. The NumPy (Numerical Python) library includes the function unique that we’ll use to summarize the die rolls. The numpy module typically is imported as np.
# 3. The random module contains Python’s random number generation functions.
# 4. The seaborn module contains the Seaborn library’s graphing capabilities we use. This module typically is imported with the name sns.

# %% [markdown]
# #### Rolling the Die and Calculating Die Frequencies
#
# Let’s use a list comprehension to create a list of 600 random die values, then use
# NumPy’s unique function to determine the unique roll values (most likely all six possible
# face values) and their frequencies:

# %%
rolls = [random.randrange(1, 7) for i in range(600)]
values, frequencies = np.unique(rolls, return_counts=True)

# %%
values
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
frequencies
# Out:
# array([100,  94, 115, 102, 102,  87])

# %% [markdown]
# Specifying the keyword argument return_counts=True tells unique to count each unique value’s number of occurrences. In this case, unique returns a tuple of two one dimensional ndarrays containing the sorted unique values and the corresponding frequencies, respectively. We unpack the tuple’s ndarrays into the variables values and frequencies. If return_counts is False, only the list of unique values is returned.

# %% [markdown]
# #### Creating the Initial Bar Plot

# %% [markdown]
# Let’s create the bar plot’s title, set its style, then graph the die faces and frequencies:

# %%
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))
# Out:
# C:\Users\khoi\AppData\Local\Temp\ipykernel_12820\2524803919.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))

# %% [markdown]
# By default, Seaborn plots graphs on a plain white background, but it provides several
# styles to choose from ('darkgrid', 'whitegrid', 'dark', 'white' and 'ticks').
#
# Function barplot’s first two arguments are ndarrays containing the x-axis and y-axis values,
# respectively. We used the optional palette keyword argument to choose Seaborn’s predefined color palette 'bright'. You can view the palette options at:
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %% [markdown]
# #### Setting the Window Title and Labeling the x- and y-Axes

# %%
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("rocket"))
title = f'Rolling a Six-Sided Die {len(rolls):,} Times'
axes.set_title(title)
axes.set(xlabel='Die Value', ylabel='Frequency')
# Out:
# C:\Users\khoi\AppData\Local\Temp\ipykernel_12820\3691368180.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("rocket"))
# [Text(0.5, 0, 'Die Value'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# #### Finalizing the Bar Plot

# %%
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))
title = f'Rolling a Six-Sided Die {len(rolls):,} Times'
axes.set_title(title)
axes.set(xlabel='Die Value', ylabel='Frequency') 
axes.set_ylim(top=max(frequencies) * 1.15)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0
    text_y = bar.get_height()
    text = f'{frequency:,}\n{frequency / len(rolls):.3%}'
    axes.text(text_x, text_y, text, fontsize=11, ha='center', va='bottom')
# Out:
# C:\Users\khoi\AppData\Local\Temp\ipykernel_12820\3121273624.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))

# %% [markdown]
# The Axes object’s set_ylim method has many optional keyword arguments. Here, we use only top to change the maximum value represented by the y-axis. We multiplied the largest frequency by 1.10 to ensure that the y-axis is 15% taller than the tallest bar.
#
# The axes object’s patches collection contains two-dimensional colored shapes that
# represent the plot’s bars. The for statement uses zip to iterate through the patches and
# their corresponding frequency values. Each iteration unpacks into bar and frequency
# one of the tuples zip returns.
#
# - The first statement calculates the center x-coordinate where the text will appear. We calculate this as the sum of the bar’s left-edge x-coordinate (bar.get_x()) and half of the bar’s width (bar.get_width() / 2.0).
# - The second statement gets the y-coordinate where the text will appear — bar.get_y() represents the bar’s top.
# - The third statement creates a two-line string containing that bar’s frequency and the corresponding percentage of the total die rolls.
# - The last statement calls the Axes object’s text method to display the text above the bar. This method’s first two arguments specify the text’s x–y position, and the third argument is the text to display. The keyword argument ha specifies the hor izontal alignment — we centered text horizontally around the x-coordinate. The keyword argument va specifies the vertical alignment — we aligned the bottom of the text with at the y-coordinate.

# %%
rolls = [random.randrange(1, 7) for i in range(6000)]
values, frequencies = np.unique(rolls, return_counts=True)

# %%
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))
title = f'Rolling a Six-Sided Die {len(rolls):,} Times'
axes.set_title(title)
axes.set(xlabel='Die Value', ylabel='Frequency') 
axes.set_ylim(top=max(frequencies) * 1.15)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0
    text_y = bar.get_height()
    text = f'{frequency:,}\n{frequency / len(rolls):.3%}'
    axes.text(text_x, text_y, text, fontsize=11, ha='center', va='bottom')
# Out:
# C:\Users\khoi\AppData\Local\Temp\ipykernel_12820\3121273624.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))

# %%
rolls = [random.randrange(1, 7) for i in range(6000000)]
values, frequencies = np.unique(rolls, return_counts=True)

# %%
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))
title = f'Rolling a Six-Sided Die {len(rolls):,} Times'
axes.set_title(title)
axes.set(xlabel='Die Value', ylabel='Frequency') 
axes.set_ylim(top=max(frequencies) * 1.15)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0
    text_y = bar.get_height()
    text = f'{frequency:,}\n{frequency / len(rolls):.3%}'
    axes.text(text_x, text_y, text, fontsize=11, ha='center', va='bottom')
# Out:
# C:\Users\khoi\AppData\Local\Temp\ipykernel_12820\3121273624.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))

# %% [markdown]
# #### Exercies

# %% [markdown]
# Modify the script above to simulate rolling two dice. Calculate the sum of the two values. Each die has a value from 1 to 6, so the sum of the values will vary from 2 to 12, with 7 being the most frequent sum, and 2 and 12 the least frequent.

# %%
# Combine the two rolls
roll =  [random.randrange(1, 7) + random.randrange(1, 7) for i in range(6000000)]
values, frequencies = np.unique(roll, return_counts=True)

#copy pasted
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))
title = f'Rolling a Six-Sided Die {len(roll):,} Times'
axes.set_title(title)
axes.set(xlabel='Die Value', ylabel='Frequency') 
axes.set_ylim(top=max(frequencies) * 1.15)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0
    text_y = bar.get_height()
    text = f'{frequency:,}\n{frequency / len(rolls):.3%}'
    axes.text(text_x, text_y, text, fontsize=11, ha='center', va='bottom')
# Out:
# C:\Users\khoi\AppData\Local\Temp\ipykernel_12820\1698749031.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))
# C:\Users\khoi\AppData\Local\Temp\ipykernel_12820\1698749031.py:7: UserWarning:
# The palette list has fewer values (6) than needed (11) and will cycle, which may produce an uninterpretable plot.
#   axes = sns.barplot(x=values, y=frequencies, palette=sns.color_palette("Blues"))
