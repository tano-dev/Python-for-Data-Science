# %% [markdown]
# ## 3.3 Plot Distributions

# %% [markdown]
# Standard imports

# %%
import numpy as np
import scipy.stats
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as pp

from IPython import display
from ipywidgets import interact, widgets

# %matplotlib inline

# %%
import re
import mailbox
import csv

# %%
china1965 = pd.read_csv('income-1965-china.csv')
china2015 = pd.read_csv('income-2015-china.csv')
usa1965 = pd.read_csv('income-1965-usa.csv')
usa2015 = pd.read_csv('income-2015-usa.csv')

# %%
china1965.income
# Out:
# 0      1.026259
# 1      0.912053
# 2      0.110699
# 3      0.469659
# 4      0.374626
#          ...
# 995    0.755723
# 996    0.608742
# 997    0.422609
# 998    0.680230
# 999    0.464976
# Name: income, Length: 1000, dtype: float64

# %%
china1965.income.plot(kind='box')

# %%
china1965.log10_income.plot.box()

# %%
pd.DataFrame({'usa': usa1965.log10_income, 'china': china1965.log10_income})
# Out:
#           usa     china
# 0    1.329679  0.011257
# 1    1.485780 -0.039980
# 2    1.702205 -0.955857
# 3    1.777926 -0.328217
# 4    1.327795 -0.426402
# ..        ...       ...
# 995  1.099734 -0.121638
# 996  1.441619 -0.215567
# 997  1.203152 -0.374061
# 998  1.498587 -0.167344
# 999  1.764610 -0.332569
#
# [1000 rows x 2 columns]

# %%
pd.DataFrame({'usa': usa1965.log10_income, 'china': china1965.log10_income}).boxplot()

# %%
china1965.income.plot(kind='hist',histtype='step',bins=20)

pp.axvline(china1965.income.mean(),c='C1',linestyle='-.')
pp.axvline(china1965.income.median(),c='C2',linestyle='--')
pp.axvline(china1965.income.quantile(0.25),c='C3',linestyle=':')
pp.axvline(china1965.income.quantile(0.75),c='C4',linestyle=':')

# %%
china1965.income.plot(kind='hist',histtype='step',bins=20,density=True)
china1965.income.plot.density(bw_method=0.5)

pp.axis(xmin=0,xmax=3)
# Out:
# (0, 3, 0.0, 1.197251489435649)

# %%
china1965.log10_income.plot.hist(histtype='step',bins=20)
usa1965.log10_income.plot.hist(histtype='step',bins=20)

# %%
china1965.income.plot.hist(histtype='step',bins=20)
usa1965.income.plot.hist(histtype='step',bins=20)

# %%
china1965.log10_income.plot.hist(histtype='step',bins=20)
usa1965.log10_income.plot.hist(histtype='step',bins=20)

levels = [0.25,0.5,1,2,4,8,16,32,64]
pp.xticks(np.log10(levels),levels);

# %%
china2015.log10_income.plot.hist(histtype='step',bins=20)
usa2015.log10_income.plot.hist(histtype='step',bins=20)

levels = [0.25,0.5,1,2,4,8,16,32,64]
pp.xticks(np.log10(levels),levels);

# %%
gapminder = pd.read_csv('gapminder.csv')

# %%
china_pop2015 = float(gapminder.query('country == "China" and year == 2015').population)

# %%
usa_pop2015 = float(gapminder.query('country == "United States" and year == 2015').population)

# %%
china_pop2015, usa_pop2015
# Out:
# (1376048943.0, 321773631.0)

# %%
china2015['weight'] = china_pop2015 / len(china2015)
usa2015['weight'] = usa_pop2015 / len(usa2015)

# %%
china2015.log10_income.plot.hist(histtype='step',bins=20,weights=china2015.weight)
usa2015.log10_income.plot.hist(histtype='step',bins=20,weights=usa2015.weight)

levels = [0.25,0.5,1,2,4,8,16,32,64]
pp.xticks(np.log10(levels),levels);
