# %% [markdown]
# ## 3.2 Describe Distributions

# %% [markdown]
# Standard imports

# %%
import numpy as np
import scipy.stats
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as pp

from IPython import display
from ipywidgets import interact, widgets

#%matplotlib inline

# %%
import re
import mailbox
import csv

# %%
china1965 = pd.read_csv('income-1965-china.csv')
china2015 = pd.read_csv('income-2015-china.csv')
usa1965 = pd.read_csv('income-1965-usa.csv')
usa2015 = pd.read_csv('income-2015-usa.csv')

# %%
china1965.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   income        1000 non-null   float64
#  1   log10_income  1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
china1965.head()
# Out:
#      income  log10_income
# 0  1.026259      0.011257
# 1  0.912053     -0.039980
# 2  0.110699     -0.955857
# 3  0.469659     -0.328217
# 4  0.374626     -0.426402

# %%
china1965.min()
# Out:
# income          0.041968
# log10_income   -1.377078
# dtype: float64

# %%
china1965.max()
# Out:
# income          5.426802
# log10_income    0.734544
# dtype: float64

# %%
china1965.mean()
# Out:
# income          0.660597
# log10_income   -0.274157
# dtype: float64

# %%
china1965.var(ddof=0)
# Out:
# income          0.208846
# log10_income    0.088610
# dtype: float64

# %%
china1965.quantile([0.25,0.75])
# Out:
#         income  log10_income
# 0.25  0.344130     -0.463277
# 0.75  0.863695     -0.063640

# %%
china1965.quantile(0.955)
# Out:
# income          1.497868
# log10_income    0.175473
# Name: 0.955, dtype: float64

# %%
china1965.median()
# Out:
# income          0.557477
# log10_income   -0.253773
# dtype: float64

# %%
scipy.stats.percentileofscore(china1965.income,1.5)
# Out:
# 95.5

# %%
china1965.describe()
# Out:
#             income  log10_income
# count  1000.000000   1000.000000
# mean      0.660597     -0.274157
# std       0.457226      0.297822
# min       0.041968     -1.377078
# 25%       0.344130     -0.463277
# 50%       0.557477     -0.253773
# 75%       0.863695     -0.063640
# max       5.426802      0.734544

# %%
china2015.describe()
# Out:
#             income  log10_income
# count  1000.000000   1000.000000
# mean     10.004892      0.896641
# std       7.581454      0.302017
# min       0.509285     -0.293039
# 25%       5.040247      0.702452
# 50%       7.860986      0.895477
# 75%      12.765222      1.106028
# max      53.661611      1.729664

# %%
usa1965.describe()
# Out:
#             income  log10_income
# count  1000.000000   1000.000000
# mean     31.587965      1.418835
# std      22.101531      0.262200
# min       4.177852      0.620953
# 25%      17.498592      1.243003
# 50%      26.069531      1.416133
# 75%      39.017113      1.591255
# max     246.030397      2.390989

# %%
usa2015.describe()
# Out:
#             income  log10_income
# count  1000.000000   1000.000000
# mean     60.710697      1.667228
# std      53.664899      0.314107
# min       4.883807      0.688758
# 25%      29.510151      1.469966
# 50%      46.189312      1.664541
# 75%      73.009663      1.863380
# max     701.518769      2.846039
