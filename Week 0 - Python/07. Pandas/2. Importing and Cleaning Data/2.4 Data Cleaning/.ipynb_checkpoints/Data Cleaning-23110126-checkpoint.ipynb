# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Standard imports

# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as pp

# %%
#billboard = pd.read_csv('billboard.csv')

# %% [markdown]
# In Unix or MacOS, we can easily find out the encoding with a command line ultility, file. In Windows, you may have to open the file with an editor.

# %%
# !file billboard.csv
# Out:
# billboard.csv: CSV text

# %%
billboard = pd.read_csv('billboard.csv',encoding='latin-1')

# %% [markdown]
# In Pandas, we can use head to see the first few lines of a table.

# %%
billboard
# Out:
#      year      artist.inverted                                  track  time  \
# 0    2000      Destiny's Child               Independent Women Part I  3:38
# 1    2000              Santana                           Maria, Maria  4:18
# 2    2000        Savage Garden                     I Knew I Loved You  4:07
# 3    2000              Madonna                                  Music  3:45
# 4    2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..    ...                  ...                                    ...   ...
# 312  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 313  2000          Smith, Will                            Freakin' It  3:58
# 314  2000        Zombie Nation                          Kernkraft 400  3:30
# 315  2000       Eastsidaz, The                               Got Beef  3:58
# 316  2000               Fragma                         Toca's Miracle  3:22
#
# ...

# %% [markdown]
# Let's look at the name of the columns.

# %%
billboard.columns
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked', 'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week',
#        'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week',
#        'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week',
#        'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week',
#        'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week',
#        'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week',
#        'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week',
#        'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week',
#        'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
# ...

# %% [markdown]
# We can plot the evolution of the ranking for any given song.

# %%
pp.plot(billboard.loc[0,'x1st.week':'x76th.week'])

# %%
pp.plot(billboard.loc[1,'x1st.week':'x76th.week'])

# %% [markdown]
# We're going to tell plot explicitly to use a range of one through 76.

# %%
pp.plot(range(1,77),billboard.loc[2,'x1st.week':'x76th.week'],color='#880088',alpha=1.0)

# %%
for i in range(0,317):
    pp.plot(range(1,77),billboard.loc[i,'x1st.week':'x76th.week'],color='#880088',alpha=0.5)

# %% [markdown]
# Plot several songs at once:
# We can iterate over rows with the DataFrame method iterrows, which yields both the index and the content of the row.

# %%
for index, row in billboard.iterrows():
    pp.plot(range(1,77),row['x1st.week':'x76th.week'],color='#ff00ff',alpha=0.1)

# %% [markdown]
# One problem with this DataFrame is that the rankings are not very usable for analysis because they're divided over multiple columns.
#
# It would make more sense to have each ranking in a separate row with the week number as a variable.
#
# Technically, this is called melting each row into multiple ones, each of which represent a single ranking.

# %%
bshort = billboard[['artist.inverted','track','time','date.entered','x1st.week','x2nd.week','x3rd.week']]

# %%
bshort.head()
# Out:
#        artist.inverted                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  x1st.week  x2nd.week  x3rd.week
# 0   2000-09-23         78       63.0       49.0
# 1   2000-02-12         15        8.0        6.0
# 2   1999-10-23         71       48.0       43.0
# 3   2000-08-12         41       23.0       18.0
# 4   2000-08-05         57       47.0       45.0

# %% [markdown]
# We should also rename the columns to better, simpler, and more consistent variable names. We can do that by assigning directly to the columns attribute.

# %%
bshort.columns = ['artist','track','time','date.entered','wk1','wk2','wk3']
bshort.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  wk1   wk2   wk3
# 0   2000-09-23   78  63.0  49.0
# 1   2000-02-12   15   8.0   6.0
# 2   1999-10-23   71  48.0  43.0
# 3   2000-08-12   41  23.0  18.0
# 4   2000-08-05   57  47.0  45.0

# %% [markdown]
# Làm lại cho 76 tuần

# %%
id_vars = ['artist.inverted','track','time','date.entered']
week_columns = []
for col in billboard.columns:
  if col.startswith('x') and col.endswith('week'):
    week_columns.append(col)
bshort = billboard[id_vars + week_columns]

bshort.head()
# Out:
#        artist.inverted                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  x1st.week  x2nd.week  x3rd.week  x4th.week  x5th.week  \
# 0   2000-09-23         78       63.0       49.0       33.0       23.0
# 1   2000-02-12         15        8.0        6.0        5.0        2.0
# 2   1999-10-23         71       48.0       43.0       31.0       20.0
# 3   2000-08-12         41       23.0       18.0       14.0        2.0
# 4   2000-08-05         57       47.0       45.0       29.0       23.0
#
#    x6th.week  ...  x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  \
# ...

# %%
new_column_names = ['artist','track','time','date.entered'] + ['wk' + str(i) for i in range(1, 77)]
bshort.columns = new_column_names
bshort.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  wk1   wk2   wk3   wk4   wk5   wk6  ...  wk67  wk68  wk69  \
# 0   2000-09-23   78  63.0  49.0  33.0  23.0  15.0  ...   NaN   NaN   NaN
# 1   2000-02-12   15   8.0   6.0   5.0   2.0   3.0  ...   NaN   NaN   NaN
# 2   1999-10-23   71  48.0  43.0  31.0  20.0  13.0  ...   NaN   NaN   NaN
# 3   2000-08-12   41  23.0  18.0  14.0   2.0   1.0  ...   NaN   NaN   NaN
# 4   2000-08-05   57  47.0  45.0  29.0  23.0  18.0  ...   NaN   NaN   NaN
#
#    wk70  wk71  wk72  wk73  wk74  wk75  wk76
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# We get to melting using the Pandas melt method.
#
# Melt requires that we specify which should be the identifier variables that are repeated for several rows. In our case, we need artist, track, time, and date.entered.
#
# Next we tell melt which should be the values, or observation columns. In this case, week one, week two, and week three.
#
# Next what should be the name of the column that holds the type of observation. It would be week.
#
# And what should be the name of the column that holds the value of the observation. It should be rank.

# %%
bmelt = bshort.melt(['artist','track','time','date.entered'],['wk1','wk2','wk3'],'week','rank')
bmelt.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered week  rank
# 0   2000-09-23  wk1  78.0
# 1   2000-02-12  wk1  15.0
# 2   1999-10-23  wk1  71.0
# 3   2000-08-12  wk1  41.0
# 4   2000-08-05  wk1  57.0

# %% [markdown]
# 76 tuần

# %%
value_vars = ['wk' + str(i) for i in range(1, 77)]
bmelt = bshort.melt(['artist','track','time','date.entered'], value_vars,'week','rank')
bmelt.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered week  rank
# 0   2000-09-23  wk1  78.0
# 1   2000-02-12  wk1  15.0
# 2   1999-10-23  wk1  71.0
# 3   2000-08-12  wk1  41.0
# 4   2000-08-05  wk1  57.0

# %% [markdown]
# To see that this works, it's better to select a specific song.
#
# We can do that with the Pandas method query which takes a query as a string
# in something like a natural language specification.

# %%
bmelt.query('track == "Independent Women Part I"')
# Out:
#                 artist                     track  time date.entered  week  \
# 0      Destiny's Child  Independent Women Part I  3:38   2000-09-23   wk1
# 317    Destiny's Child  Independent Women Part I  3:38   2000-09-23   wk2
# 634    Destiny's Child  Independent Women Part I  3:38   2000-09-23   wk3
# 951    Destiny's Child  Independent Women Part I  3:38   2000-09-23   wk4
# 1268   Destiny's Child  Independent Women Part I  3:38   2000-09-23   wk5
# ...                ...                       ...   ...          ...   ...
# 22507  Destiny's Child  Independent Women Part I  3:38   2000-09-23  wk72
# 22824  Destiny's Child  Independent Women Part I  3:38   2000-09-23  wk73
# 23141  Destiny's Child  Independent Women Part I  3:38   2000-09-23  wk74
# 23458  Destiny's Child  Independent Women Part I  3:38   2000-09-23  wk75
# 23775  Destiny's Child  Independent Women Part I  3:38   2000-09-23  wk76
#
#        rank
# 0      78.0
# 317    63.0
# 634    49.0
# 951    33.0
# ...

# %%
bmelt.query('artist == "Savage Garden"')
# Out:
#               artist               track  time date.entered  week  rank
# 2      Savage Garden  I Knew I Loved You  4:07   1999-10-23   wk1  71.0
# 94     Savage Garden      Crash And Burn  4:41   2000-04-08   wk1  75.0
# 319    Savage Garden  I Knew I Loved You  4:07   1999-10-23   wk2  48.0
# 411    Savage Garden      Crash And Burn  4:41   2000-04-08   wk2  58.0
# 636    Savage Garden  I Knew I Loved You  4:07   1999-10-23   wk3  43.0
# ...              ...                 ...   ...          ...   ...   ...
# 23235  Savage Garden      Crash And Burn  4:41   2000-04-08  wk74   NaN
# 23460  Savage Garden  I Knew I Loved You  4:07   1999-10-23  wk75   NaN
# 23552  Savage Garden      Crash And Burn  4:41   2000-04-08  wk75   NaN
# 23777  Savage Garden  I Knew I Loved You  4:07   1999-10-23  wk76   NaN
# 23869  Savage Garden      Crash And Burn  4:41   2000-04-08  wk76   NaN
#
# [152 rows x 6 columns]

# %% [markdown]
# Converting the week to a number:
#
# You can do using the apply method on the Pandas series for the column week. Apply takes a Python function. And we're going to define it on-the-fly using lambda. We need the third character in each string and we need to turn that
# into a number, an integer.

# %%
bmelt['week'] = bmelt['week'].apply(lambda s: int(s[2]))

# %%
bmelt.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  week  rank
# 0   2000-09-23     1  78.0
# 1   2000-02-12     1  15.0
# 2   1999-10-23     1  71.0
# 3   2000-08-12     1  41.0
# 4   2000-08-05     1  57.0

# %% [markdown]
# Once we have true dates, we can do date arithmetic and apply, for instance, Timedeltas, obtaining the correct date for each ranking in week one, two, and three.

# %%
bmelt['date.entered'] = pd.to_datetime(bmelt['date.entered'])

# %%
bmelt['date.entered'][0]
# Out:
# Timestamp('2000-09-23 00:00:00')

# %%
bmelt['date.entered'][0] + pd.Timedelta('7 days')
# Out:
# Timestamp('2000-09-30 00:00:00')

# %%
bmelt['date'] = bmelt['date.entered'] + pd.Timedelta('7 days') * (bmelt['week'] - 1)

# %%
bmelt.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  week  rank       date
# 0   2000-09-23     1  78.0 2000-09-23
# 1   2000-02-12     1  15.0 2000-02-12
# 2   1999-10-23     1  71.0 1999-10-23
# 3   2000-08-12     1  41.0 2000-08-12
# 4   2000-08-05     1  57.0 2000-08-05

# %%
bmelt.query('week == "2"')
# Out:
# Empty DataFrame
# Columns: [artist, track, time, date.entered, week, rank, date]
# Index: []

# %% [markdown]
# At this point, we may as well drop the column date.entered. We need to tell Pandas that we're working with the columns, so axis 1.

# %%
bmelt.drop(['date.entered'],axis=1,inplace=True)

# %% [markdown]
# We sort both the columns and the rows. Artist, track, time, date, week, and rank.

# %%
bfinal = bmelt[['artist','track','time','date','week','rank']]
bfinal.sort_values(['artist','track'],inplace=True)

# %%
bfinal.head()
# Out:
#      artist                                track  time       date  week  rank
# 246   2 Pac  Baby Don't Cry (Keep Ya Head Up II)  4:22 2000-02-26     1  87.0
# 563   2 Pac  Baby Don't Cry (Keep Ya Head Up II)  4:22 2000-03-04     2  82.0
# 880   2 Pac  Baby Don't Cry (Keep Ya Head Up II)  4:22 2000-03-11     3  72.0
# 1197  2 Pac  Baby Don't Cry (Keep Ya Head Up II)  4:22 2000-03-18     4  77.0
# 1514  2 Pac  Baby Don't Cry (Keep Ya Head Up II)  4:22 2000-03-25     5  87.0

# %% [markdown]
# The artist name, the track name, and the track length appear in multiple rows.
# The correct way to remove the redundancy is to create a separate table with track data and linking it to the rankings using an index.
#
# In the context of relational databases, this is called data normalization.

# %%
tracks = bfinal[['artist','track','time']].drop_duplicates()
tracks.head()
# Out:
#            artist                                              track  time
# 246         2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 287       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 24   3 Doors Down                                         Kryptonite  3:53
# 193  3 Doors Down                                              Loser  4:24
# 69       504 Boyz                                      Wobble Wobble  3:35

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 317 entries, 246 to 15
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  317 non-null    object
#  1   track   317 non-null    object
#  2   time    317 non-null    object
# dtypes: object(3)
# memory usage: 9.9+ KB

# %% [markdown]
# The index is unique and we need to carry it explicitly as a column. So, we reset the index and rename it id. We can assign directly to index.name.

# %%
tracks.index.name = 'id'
tracksid = tracks.reset_index()
tracksid.head()
# Out:
#     id        artist                                              track  time
# 0  246         2 Pac                Baby Don't Cry (Keep Ya Head Up II)  4:22
# 1  287       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...  3:15
# 2   24  3 Doors Down                                         Kryptonite  3:53
# 3  193  3 Doors Down                                              Loser  4:24
# 4   69      504 Boyz                                      Wobble Wobble  3:35

# %% [markdown]
# We now perform a database style join operation between the new table of tracks and the Billboard table. We do so by matching by artist and track.

# %%
pd.merge(tracksid,bfinal,on=['track','artist']).head()
# Out:
#     id artist                                track time_x time_y       date  \
# 0  246  2 Pac  Baby Don't Cry (Keep Ya Head Up II)   4:22   4:22 2000-02-26
# 1  246  2 Pac  Baby Don't Cry (Keep Ya Head Up II)   4:22   4:22 2000-03-04
# 2  246  2 Pac  Baby Don't Cry (Keep Ya Head Up II)   4:22   4:22 2000-03-11
# 3  246  2 Pac  Baby Don't Cry (Keep Ya Head Up II)   4:22   4:22 2000-03-18
# 4  246  2 Pac  Baby Don't Cry (Keep Ya Head Up II)   4:22   4:22 2000-03-25
#
#    week  rank
# 0     1  87.0
# 1     2  82.0
# 2     3  72.0
# 3     4  77.0
# 4     5  87.0

# %%
pd.merge(tracksid,bfinal,on=['track','artist','time']).head()
# Out:
#     id artist                                track  time       date  week  \
# 0  246  2 Pac  Baby Don't Cry (Keep Ya Head Up II)  4:22 2000-02-26     1
# 1  246  2 Pac  Baby Don't Cry (Keep Ya Head Up II)  4:22 2000-03-04     2
# 2  246  2 Pac  Baby Don't Cry (Keep Ya Head Up II)  4:22 2000-03-11     3
# 3  246  2 Pac  Baby Don't Cry (Keep Ya Head Up II)  4:22 2000-03-18     4
# 4  246  2 Pac  Baby Don't Cry (Keep Ya Head Up II)  4:22 2000-03-25     5
#
#    rank
# 0  87.0
# 1  82.0
# 2  72.0
# 3  77.0
# 4  87.0

# %%
tidy = pd.merge(tracksid,bfinal,on=['track','artist','time']).drop(['artist','track','time'],axis=1)
tidy.head()
# Out:
#     id       date  week  rank
# 0  246 2000-02-26     1  87.0
# 1  246 2000-03-04     2  82.0
# 2  246 2000-03-11     3  72.0
# 3  246 2000-03-18     4  77.0
# 4  246 2000-03-25     5  87.0

# %%
tidy.query('week == 1')
# Out:
#         id       date  week  rank
# 0      246 2000-02-26     1  87.0
# 9      246 2000-02-26     1   NaN
# 10     246 2000-02-26     1   NaN
# 11     246 2000-02-26     1   NaN
# 12     246 2000-02-26     1   NaN
# ...    ...        ...   ...   ...
# 24030   15 2000-04-29     1   3.0
# 24031   15 2000-04-29     1   2.0
# 24032   15 2000-04-29     1   2.0
# 24033   15 2000-04-29     1   3.0
# 24034   15 2000-04-29     1   4.0
#
# [3487 rows x 4 columns]

# %%
tidy[tidy.week == 1]
# Out:
#         id       date  week  rank
# 0      246 2000-02-26     1  87.0
# 9      246 2000-02-26     1   NaN
# 10     246 2000-02-26     1   NaN
# 11     246 2000-02-26     1   NaN
# 12     246 2000-02-26     1   NaN
# ...    ...        ...   ...   ...
# 24030   15 2000-04-29     1   3.0
# 24031   15 2000-04-29     1   2.0
# 24032   15 2000-04-29     1   2.0
# 24033   15 2000-04-29     1   3.0
# 24034   15 2000-04-29     1   4.0
#
# [3487 rows x 4 columns]

# %%
tidy[tidy.week == 1]['rank'].idxmin()
# Out:
# 621

# %%
tidy.loc[tidy[tidy.week == 1]['rank'].idxmin()]
# Out:
# id                       14
# date    2000-03-18 00:00:00
# week                      1
# rank                    1.0
# Name: 621, dtype: object

# %%
tracksid[tracksid.id == 1]
# Out:
#      id   artist         track  time
# 252   1  Santana  Maria, Maria  4:18

# %%
tracksid[tracksid.id == tidy.loc[tidy[tidy.week == 1]['rank'].idxmin()]['id']]
# Out:
#    id   artist      track  time
# 8  14  Aaliyah  Try Again  4:03

# %%
tracksid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      317 non-null    int64
#  1   artist  317 non-null    object
#  2   track   317 non-null    object
#  3   time    317 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 10.0+ KB
