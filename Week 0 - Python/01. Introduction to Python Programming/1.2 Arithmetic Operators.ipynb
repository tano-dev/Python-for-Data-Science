# %% [markdown]
# <h1 align="center">Introduction to Python Programming</h1>

# %% [markdown]
# ## 1.2 Arithmetic

# %% [markdown]
# Many programs perform <b>arithmetic calculations</b>. The following table summarizes the arithmetic operators, which include some symbols not used in algebra.

# %% [markdown]
# ![2.3 Arithmetic Operators.png](attachment:eb06cb70-a460-4fd6-84af-ca9629405cb7.png)

# %%
7 * 5
# Out:
# 35

# %%
2 ** 5
# Out:
# 32

# %%
25 ** (1 / 2)
# Out:
# 5.0

# %%
7 / 4
# Out:
# 1.75

# %%
7 // 4
# Out:
# 1

# %%
3 // 5
# Out:
# 0

# %%
14 // 7
# Out:
# 2

# %%
-13 / 4
# Out:
# -3.25

# %%
-13 // 4
# Out:
# -4

# %% [markdown]
# #### Exceptions and Tracebacks

# %%
x=7

123 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 x=7
# ----> 3 123 / 0
#
# ZeroDivisionError: division by zero

# %%
z=int(input("Nhap so z= "))
z +7
# Out:
# Nhap so z=  7
# 14

# %%
17 % 5
# Out:
# 2

# %%
7.5 % 3.5
# Out:
# 0.5

# %%
10 * (5 + 3)
# Out:
# 80

# %%
10 * 5 + 3
# Out:
# 53

# %% [markdown]
# https://docs.python.org/3/reference/expressions.html#operator-precedence

# %%
value = input("What's your name?")
# Out:
# What's your name? Alice

# %%
value
# Out:
# 'Alice'

# %%
value = int(input("Enter a number:"))
# Out:
# Enter a number: 9

# %%
value
# Out:
# 9

# %%
type(value)
# Out:
# int
